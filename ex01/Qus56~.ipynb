# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Datamanim/pandas/main/BankChurnersUp.csv', index_col=0)
df
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
df.shape
# Out:
# (10127, 18)

# %%
dic = {
    'Unknown'        : 'N',
    'Less than $40K' : 'a',
    '$40K - $60K'    : 'b',
    '$60K - $80K'    : 'c',
    '$80K - $120K'   : 'd',
    '$120K +'        : 'e'   
}

df['newIncome'] = df['Income_Category'].map(lambda x: dic[x])

Ans = df['newIncome']

# %%
df
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
def changeCategory(x):
    if x == "Unknown" :
        return "N"
    elif x == "Less than $40K" : 
        return "a"
    elif x == "$40K - $60K" :
        return "b"
    elif x == "$60K - $80K" : 
        return "c"
    elif x == "$80K - $120K" :
        return "d"
    elif x == "$120K +’" :
        return "e"

df['newIncome'] = df['Income_Category'].apply(changeCategory)
df
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
df['AgeState'] = df['Customer_Age'].map(lambda x : x//10 * 10)

df.value_counts('AgeState').sort_index()
# Out:
# AgeState
# 20     195
# 30    1841
# 40    4561
# 50    2998
# 60     530
# 70       2
# Name: count, dtype: int64

# %%
def f1(x):
    if 'Graduate' in x :
        return 1
    else: return 0

df['newEduLevel'] = df['Education_Level'].apply(f1)

# %%
df['newEduLevel'].value_counts()
# Out:
# newEduLevel
# 0    6483
# 1    3644
# Name: count, dtype: int64

# %%
df['newLimit'] = df['Credit_Limit'].map(lambda x : 1 if x >= 4500 else 0)
df.value_counts('newLimit')
# Out:
# newLimit
# 1    5096
# 0    5031
# Name: count, dtype: int64

# %%
df
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
def f2(x):
    Status = x['Marital_Status']
    Card = x['Card_Category']

    if (Status == 'Married') & (Card == 'Platinum'):
        return 1
    else : return 0


df['newState'] = df[['Marital_Status', 'Card_Category']].apply(f2, axis=1)

# %%
df.value_counts('newState')
# Out:
# newState
# 0    10120
# 1        7
# Name: count, dtype: int64

# %%
df['Gender'] = df['Gender'].map(lambda x: 'male' if x == 'M' else 'female')
df.value_counts('Gender')
# Out:
# Gender
# female    5358
# male      4769
# Name: count, dtype: int64
