# %% [markdown]
# # 판다스
# - 데이터 분석을 위한 대표 패키지
# - 빅분기 1유형을 위한 학습

# %% [markdown]
# #### 1유형 기출 느낌을 알아보자 (회차당 3문제,30점)
# - 무조건 다 맞아야함!!
# - 판다스 학습 후 아래 문제들을 모두 풀 수 있어야함
# - 파생변수 생성, 시계열 데이터 전처리, 기초 통계량, 그룹핑 등등
#
#
# (체험환경) 데이터에서 RM 중앙값으로 해당 컬럼의 결측치를 대체하라.그리고 해당 컬럼의 결측치 대치 전후의 표준편차 차이의 절댓값을 소숫점 이하 3째자리 까지 구하라
#
#
# ---
#
# (8회) 대륙별 맥주 평균 소비량을 구하라. 5번째로 소비가 많은 대륙의 2번째로 맥주 소비량이 많은 국가의 맥주 소비량을 구하여라
# (8회) 총 방문객 수는 관광,방문,유햑연수,취업,기타 방문자 숫자의 합으로 정의한다. 각 국가별 관광 / 총 방문객 수의 비율을 구하고 이를 관광 비율이라 한다. 관광비율이 2번째로 높은 국가의 취업으로 출국한 인원과 관광 숫자가 3번째로 높은 국가의 방문으로 출국한 인원의 합을 구하여라
# (8회) CO(GT),NMHC(GT) 두 컬럼을 min-max normalize를 진행하고 각 컬럼의 모표준편차의 차이의 절댓값을 소숫점 이하 3째 자리까지 구하여라
#
# ---
#
# (7회) 국어,수학,영어,과학 과목 중 가장 많은 학생들이 응시한 시험을 선택하고 해당과목의 점수를 표준화 했을 때 가장 큰 표준화 점수를 구하여라
# (7회) 32개의 변수간 상관관계를 확인 했을 때, var_11 컬럼과 상관계수의 절댓값이 가장 큰 변수를 찾아 해당 변수의 평균값을 구하여라
# (7회) var_6 컬럼의 1,3사분위수 각각 IQR의 1.5배 벗어난 이상치의 숫자를 구하라
#
#
# ---
#
# (6회) 각 구급 보고서 별 출동시각과 신고시각의 차이를 ‘소요시간’ 컬럼을 만들고 초(sec)단위로 구하고 소방서명 별 소요시간의 평균을 오름차순으로 정렬 했을때 3번째로 작은 소요시간의 값과 소방서명을 출력하라
# (6회) 학교 세부유형이 일반중학교인 학교들 중 일반중학교 숫자가 2번째로 많은 시도의 일반중학교 데이터만 필터하여 해당 시도의 교원 한명 당 맡은 학생수가 가장 많은 학교를 찾아서 해당 학교의 교원수를 출력하라
# (6회) 5대 범죄(절도, 사기, 배임, 방화, 폭행)의 월별 총 발생건수를 총범죄수라고 표현하자. 18,19년의 각각 분기별 총범죄수의 월평균 값을 구했을때 최대값을 가지는 년도와 분기를 구하고 해당 분기의 최댓값의 사기가 발생한 월의 사기 발생건수를 출력하라(1분기:1,2,3월 / 2분기 : 4,5,6월 / 3분기 7,8,9월 / 4분기 10,11,12월 , 1분기 월평균 : 1,2,3월의 총범죄수 평균)
#
# ---
#
# (5회) 20L가격과 5L가격이 모두 0원이 아닌 데이터만 필터를 한 후, 각 row별로 20L가격과 5L가격의 차이를 ‘차이가격’ 이라 부른다고 하자. 시도명 별 차이가격의 평균가격을 비교할때 그 값이 가장 큰 금액을 반올림하여 소숫점 이하 1자리까지 구하여라
# (5회) BMI는 몸무게(kg) / (키(M) * 키(M)) 로 정의 된다. 초고도 비만은 BMI 25이상 , 고도 비반은 BMI 25미만 - 23이상 , 정상은 23미만 - 18.5이상 저체중은 18.5미만으로 정의 된다. 주어진 데이터에서 초고도비만 인원 + 저체중 인원 의 숫자는?
# (5회) 순유입인원은 초중고 도내,도외 전입인원에서 초중고 도내, 도외 전출인원을 뺀값이다. 각년도별로 가장 큰 순유입인원을 가진 지역구의 순유입인원을 구하고 전체 기간의 해당 순유입인원들의 합을 구하여라
#
# ---
#
# (4회) Temperature컬럼에서 숫자가 아닌 문자들을 제거후 숫자 타입으로 바꾸고 3분위수에서 1분위수의 차이를 소숫점 이하 2자리까지 구하여라
# (4회) Likes를 Comments로 나눈 비율이 20이상이면서 Keyword값이 minecraft인 영상들의 Views값의 평균을 정수로 구하여라
# (4회) date_added가 2018년 1월 이면서 country가 United Kingdom 단독 제작인 데이터의 갯수
#
# ---
#
# (3회) 결측치가 하나라도 존재하는 행의 경우 경우 해당 행을 삭제하라. 그후 남은 데이터의 상위 70%에 해당하는 데이터만 남겨둔 후 median_income 컬럼의 1분위수를 반올림하여 소숫점이하 2째자리까지 구하여라
# (3회) 1990년도는 해당년도 평균 이하 GDP를 가지지만, 2010년도에는 해당년도 평균 이상 GDP를 가지는 국가의 숫자를 구하여라
# (3회) 데이터에서 결측치가 가장 많은 컬럼을 출력하라
#
#
# ---
#
# (2회) 주어진 Dataset에서 CRIM값이 가장 큰 10개의 지역을 구하고 10개의 지역의 CRIM값을 그 중 가장 작은 값으로 대체하라. 그리고 AGE 컬럼 값이 80이상인 대체 된 CRIM 평균값을 구하라
# (2회) 데이터에서 RM 중앙값으로 해당 컬럼의 결측치를 대체하라. 그리고 해당 컬럼의 결측치 대치 전후의 표준편차 차이의 절댓값을 소숫점 이하 3째자리 까지 구하라.
# (2회) DIS 평균으로 부터 1.5 * 표준편차를 벗어나는 영역을 이상치라고 판단하고
# DIS 컬럼의 이상치들의 합을 구하여라.
#
# ---

# %% [markdown]
# #### 익혀야할 메소드, 모듈 리스트
#
# ```python
#
#
# ### 1. 기본 데이터 구조
# pd.DataFrame # DataFrame 생성
# pd.Series    # Series 생성
#
# ### 2. 데이터 로드 및 저장
# pd.read_csv # 데이터 로드 (옵션: `index_col`, `sep` : '\t', `encoding` :'cp949' ,'utf-8')
# pd.to_csv   # 데이터 저장 (옵션: `index=False`)
# pd.read_excel
#
# ### 3. 데이터 탐색 및 통계
# .head()                 # 상위 5개 행
# .tail()                 # 하위 5개 행
# .info()                 # 기초 정보
# .describe()             # 기초 통계량
# .round()                # 반올림
# .nunique()              # 고유 값의 개수
# .value_counts()         # 값의 빈도수 계산
# .corr()                 # 상관계수
# .cov()                  # 공분산
# .std()                  # 표준편차
# .abs()                  # 절댓값
# .cumsum()               # 누적합
# .skew()                 # 왜도
# .kurtosis()             # 첨도
# .quantile()             # 사분위수
# .select_dtypes()        # df.select_dtypes(include= 'object') exclude = 'object'
#
# ### 4. 데이터 선택 및 필터링
# .iloc[]                # 위치 기반 인덱싱
# .loc[]                 # 라벨 기반 인덱싱
# .index                 # 인덱스 추출
# .isin()                # 포함된 데이터 확인  df[df['col1'].isin(['data1','data2'])]
# .isnull()              # 결측치 확인 df.isnull().sum()
# .str
#
#
# ### 5. 그룹화 및 집계
# .groupby()             # 그룹핑
# .pivot()               # 피벗 테이블
# .pivot_table()         # pivot과 유사 더 많이 씀
#                        # df.pivot_table(index = 'col1', columns =['col2','col3'],values=['col4'])
#
# ### 6. 데이터 조작 및 변형
# .apply(function, axis=1) # apply(def,axis=1) 함수를 이용한 후처리 ,axis=1로 하면 행을 기준으로 실행
# .copy()                 # 복사
# .drop(columns=['col1']) # 컬럼 제거
# .drop_duplicates()       # 중복제거   drop_duplicates('col1',keep='first') col1기준으로 중복제거 첫행 남기려면 first
# .dropna()                # 결측치 제거
# .fillna()                # 결측치 채우기  fillna(method = 'ffill') # 이전행의 값 | bfill 다음행의 값
# .rename(columns={'pre': 'after'}) # 컬럼명 변경
# .reset_index(drop=True)  # 초기화 drop=True는 항상 넣어주는게 좋다
# .set_index()              # 인덱스 설정
# .sort_values('col1')     # 값 정렬
# .sort_index()             # 인덱스 정렬
#
#
# ### 7. 데이터 결합
# pd.concat([df1, df2], axis=1) # axis=1 좌우 병합 , axis=0 상하 병합
# pd.merge(df1, df2, on, how)   # index 동일할 경우에 합치기 how= 'outer' 합집합 'inner' 교집합
#
# ### 8. 범주형 데이터 처리
# pd.get_dummies(df) # 범주형 더미화 # drop_first 옵션
#
#
# ### 9. 시계열 데이터 형식 변환
# dates = pd.to_datetime(date_strings, format='%Y-%m-%d %HH:%MM:%SS')
# # 형식 코드 설명
# # %Y: 4자리 연도 (예: 2024)
# # %y: 2자리 연도 (예: 24)
# # %m: 0-padding된 2자리 월 (예: 01, 12)
#
# # %H: 24시간 형식의 시 (예: 00, 23)
# # %M: 24시간 형식의 분
# # %S: 24시간 형식의 초
#
#
# # 예시 날짜 데이터 생성
# date_data = pd.date_range('2024-01-01', periods=5, freq='D')
# df = pd.DataFrame({'dates': date_data})
#
# # 사용 가능한 .dt 메소드
# df['dates'].dt.year         # 연도 추출
# df['dates'].dt.month        # 월 추출
# df['dates'].dt.day          # 일 추출
# df['dates'].dt.hour         # 시간 추출
# df['dates'].dt.minute       # 분 추출
# df['dates'].dt.second       # 초 추출
# df['dates'].dt.weekday      # 요일(0=월요일, 6=일요일) 추출
# df['dates'].dt.dayofweek    # 요일(0=월요일, 6=일요일) 추출 (weekday와 동일)
# df['dates'].dt.dayofyear    # 연도의 몇 번째 날인지 추출
# df['dates'].dt.quarter      # 분기 추출
# df['dates'].dt.strftime('%Y-%m-%d')  # 포맷에 맞춰 문자열로 변환
# df['dates'].dt.to_period('M')  # 주기(period)로 변환 (예: 월 단위)
# ```

# %% [markdown]
# ### 패키지 import
# ```python
# import pandas as pd
#
# ```

# %% [markdown]
# ### Series와 DataFrame
# - series :Series는 pandas의 1차원 배열 구조로, 인덱스와 값으로 구성
# - DataFrame : DataFrame은 pandas의 2차원 배열 구조로, 여러 개의 Series가 모여서 이루어진 것
# - 데이터 생성
#
# ---
# ```python
#
# fruits = pd.Series(['사과', '바나나', '체리'])
# print(fruits)
#
#
# ```
# ---
#
#
# ```python
#
# data = {
#     '과일': ['사과', '바나나', '체리'],
#     '수량': [10, 5, 20]
# }
#
# data2 = [['사과',10],['바나나',5],['체리',20]]
# df = pd.DataFrame(data)
#
# ```
# ---
# - Series : index,values,type
# - DataFrame : index, columns, values, dir, 3-d

# %%
data = {
    '과일': ['사과', '바나나', '체리'],
    '수량': [10, 5, 20]
}
data2 = [  ['사과',10,5],  ['바나나',5,5],  ['체리',20,5]  ]

# %% [markdown]
# ### 데이터 읽기
#
# - pd.read_csv(path) # 데이터 경로 or url 등
# - pd.read_excel # 엑셀파일
# - csv 파일 : ',' 를 기준으로 구분 된 데이터
#
#
# ```python
# data ='https://raw.githubusercontent.com/Datamanim/datarepo/refs/heads/main/data/1.csv'  # Unamed :0
# data ='https://raw.githubusercontent.com/Datamanim/datarepo/refs/heads/main/data/2.csv'  # tab
#
# df =pd.read_csv(data)
#
#
# # 체험환경 데이터 경로 확인
#
# ```

# %% [markdown]
# ### 데이터 선택 및 필터링
#
# - 각 요소 접근방법 3가지
#    1 .values
#    2 .컬럼
#    3 [컬럼]
#    컬럼 선택 후 행은 리스트 인덱싱
# ---
#
# - 특정 컬럼 여러개 접근 [[]]
# ```python
#
#
# .index                 # 인덱스 추출,변경
# .columns               # 컬럼 추출,변경
# .iloc[]                # 위치 기반 인덱싱  [행,열]
# .loc[]                 # 라벨 기반 인덱싱  [행,열]
# .isin()                # 포함된 데이터 확인  df[df['col1'].isin(['data1','data2'])]
# .isnull()              # 결측치 확인 df.isnull().sum()
# .str.contains
#
# - 특정행 값 변경 (0,0)위치
#
#
# data ='https://raw.githubusercontent.com/Datamanim/datarepo/refs/heads/main/data/3.csv'
# ```

# %% [markdown]
# ### DataFrame 탐색 및 통계
#
# ```python
# .astype()               # 타입변경
# .head()                 # 상위 5개 행
# .tail()                 # 하위 5개 행
# .info()                 # 기초 정보
# .describe()             # 기초 통계량 .T (전치행렬)
# .round()                # 반올림
# .astype()               # 타입변경
# .nunique()              # 고유 값의 개수
# .value_counts()         # 값의 빈도수 계산
# .corr()                 # 상관계수
# .cov()                  # 공분산
# .std()                  # 표준편차
# .max()
# .min()
# .mean()
# .cumsum()               # 누적합
# .skew()                 # 왜도
# .kurtosis()             # 첨도
# .quantile()             # 사분위수
# .select_dtypes()        # df.select_dtypes(include= 'object') exclude = 'object'
#
# # 체험환경 데이터 추출 확인
# ```

# %% [markdown]
# ### 데이터 조작 및 변형
#
# ```python
# .apply(function, axis=1) # apply(def,axis=1) 함수를 이용한 후처리 ,axis=1로 하면 행을 기준으로 실행
# .map(function)
# .copy()                 # 복사
# .drop(columns=['col1']) # 컬럼 제거
# .drop_duplicates()       # 중복제거   drop_duplicates('col1',keep='first') col1기준으로 중복제거 첫행 남기려면 first
# .dropna()                # 결측치 제거 axis / how
# .fillna()                # 결측치 채우기  fillna(method = 'ffill') # 이전행의 값 | bfill 다음행의 값
# .rename(columns={'pre': 'after'}) # 컬럼명 변경
# .reset_index(drop=True)  # 초기화 drop=True는 항상 넣어주는게 좋다
# .set_index()              # 인덱스 설정
# .sort_values('col1')     # 값 정렬  ascending 내림,오름차순
# .sort_index()             # 인덱스 정렬
# ```

# %% [markdown]
# ### 그룹화 및 집계
#
# ```python
# .groupby()             # 그룹핑  groupby(기준)[컬럼].함수 .max(numeric_only=True) 등
# .pivot_table()         # pivot과 유사 더 많이 씀
#                        # df.pivot_table(index = 'col1', columns =['col2','col3'],values=['col4'])
#                        # df.pivot(index= 'ages',columns ='S',values='Age',aggfunc='mean')
#
# pd.crosstab            # 범주형 변수끼리 교차테이블 생성
# ```

# %% [markdown]
# ### 데이터 결합
#
# ```python
# pd.concat([df1, df2], axis=1) # axis=1 좌우 병합 , axis=0 상하 병합
# pd.merge(df1, df2, on, how)   # index 동일할 경우에 합치기 how= 'outer' 합집합 'inner' 교집합
#
#
# data1 ='https://raw.githubusercontent.com/Datamanim/datarepo/refs/heads/main/data/4.csv'
# data2 ='https://raw.githubusercontent.com/Datamanim/datarepo/refs/heads/main/data/5.csv'
# ```

# %% [markdown]
# ### 범주형 데이터 처리
# ```python
# pd.get_dummies(df) # 범주형 더미화 # drop_first 옵션
# ```

# %% [markdown]
# ### 시계열 데이터 형식 변환
#
# ```python
# dates = pd.to_datetime(date_strings, format='%Y-%m-%d %HH:%MM:%SS')
# # 형식 코드 설명
# # %Y: 4자리 연도 (예: 2024)
# # %y: 2자리 연도 (예: 24)
# # %m: 0-padding된 2자리 월 (예: 01, 12)
#
# # %H: 24시간 형식의 시 (예: 00, 23)
# # %M: 24시간 형식의 분
# # %S: 24시간 형식의 초
#
#
# # 예시 날짜 데이터 생성
# date_data = pd.date_range('2024-01-01', periods=5, freq='D')
# df = pd.DataFrame({'dates': date_data})
#
# # 사용 가능한 .dt 메소드
# df['dates'].dt.year         # 연도 추출
# df['dates'].dt.month        # 월 추출
# df['dates'].dt.day          # 일 추출
# df['dates'].dt.hour         # 시간 추출
# df['dates'].dt.minute       # 분 추출
# df['dates'].dt.second       # 초 추출
# df['dates'].dt.weekday      # 요일(0=월요일, 6=일요일) 추출
# df['dates'].dt.dayofweek    # 요일(0=월요일, 6=일요일) 추출 (weekday와 동일)
# df['dates'].dt.dayofyear    # 연도의 몇 번째 날인지 추출
# df['dates'].dt.quarter      # 분기 추출
# df['dates'].dt.strftime('%Y-%m-%d')  # 포맷에 맞춰 문자열로 변환
# df['dates'].dt.to_period('M')  # 주기(period)로 변환 (예: 월 단위)
#
#
# data = {
#     'date': [
#         '2023-01-01',     # 정상적인 날짜 형식 (YYYY-MM-DD)
#         '01/02/2023',     # 다른 형식의 날짜 (MM/DD/YYYY)
#         '2023.03.03',     # 점(.)으로 구분된 날짜 (YYYY.MM.DD)
#         'april 4, 2023',  # 문자로 표현된 날짜 (Month Day, Year)
#         '2023/05/05',     # 슬래시(/)로 구분된 날짜 (YYYY/MM/DD)
#         '06-06-2023',     # 하이픈(-)으로 구분된 날짜 (MM-DD-YYYY)
#         '2023-07-32',     # 잘못된 날짜 (7월에 32일 없음)
#         'random text',    # 완전히 잘못된 값
#         '',               # 빈 문자열
#         None              # None 값 (결측치)
#     ]
# }
#
#
#
# data2 ='https://raw.githubusercontent.com/Datamanim/datarepo/refs/heads/main/data/6.csv'
#
# ```
