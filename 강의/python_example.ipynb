# %% [markdown]
# ### 문제
#
# 1. 두 변수 `a = 10`, `b = 5`가 있을 때, `a + b`의 결과는?
# 2. `x = 20`일 때, `x > 15`의 결과는?
# 3. `x = 5`일 때, `x`를 문자열로 변환하는 코드는?
# 4. `a = 8`과 `b = 2`가 있을 때, `a - b`의 결과는?
# 5. `x = 10`과 `y = 3`이 있을 때, `x * y`의 결과는?
# 6. `a = 15`일 때, `a % 4`의 결과는?
# 7. `x = 30`일 때, `x < 50`의 결과는?
# 8. `x = 5`를 정수형에서 부동소수점형으로 변환하는 코드는?
# 9. `x = 3.14`일 때, `x`를 정수로 변환하는 코드는?
# 10. `a = 5`와 `b = 10`일 때, `a += b` 후의 `a`의 값은?
# 11. 리스트 `numbers = [1, 2, 3, 4, 5]`에서 `numbers[2]`의 값은?
# 12. 리스트 `items = ['apple', 'banana', 'cherry']`에서 인덱스 1의 값을 출력하는 코드는?
# 13. 리스트 `fruits = ['apple', 'banana', 'cherry']`에 `'orange'`를 추가하는 코드는?
# 14. 리스트 `my_list = [10, 20, 30, 40]`에서 마지막 요소를 추출하는 코드는?
# 15. 문자열 `text = "Hello"`에서 첫 번째 문자를 출력하는 코드는?
# 16. `x = 100`일 때, `x // 3`의 결과는?
# 17. `x = 7`일 때, `x ** 2`의 결과는?
# 18. 리스트 `numbers = [1, 2, 3]`의 길이를 구하는 코드는?
# 19. 리스트 `values = [5, 10, 15]`에서 두 번째 요소를 20으로 변경하는 코드는?
# 20. `x = "Python"`에서 `"P"`의 인덱스를 찾는 코드는?
# 21. 문자열 `s = "   Hello   "`에서 양쪽 공백을 제거하는 코드는?
# 22. 리스트 `my_list = [1, 2, 3]`에서 모든 요소에 2를 더한 새로운 리스트를 만드는 코드는?
# 23. 딕셔너리 `my_dict = {'a': 1, 'b': 2}`에서 키 `'b'`의 값을 출력하는 코드는?
# 24. 딕셔너리 `my_dict = {'a': 1, 'b': 2}`에 키 `'c'`와 값 `3`을 추가하는 코드는?
# 25. `x = "hello"`에서 문자열을 대문자로 변환하는 코드는?
# 26. `x = "123"`에서 숫자 문자열을 정수로 변환하는 코드는?
# 27. `x = [1, 2, 3]`의 각 요소를 제곱한 새로운 리스트를 만드는 코드는?
# 28. `for`문을 사용하여 리스트 `my_list = [1, 2, 3]`의 모든 요소를 출력하는 코드는?
# 29. `for`문을 사용하여 `range(5)`에서 숫자를 출력하는 코드는?
# 30. `x = 10`일 때, `if x > 5:` 블록 안에 실행할 코드 한 줄은?
# 31. `my_list = [1, 2, 3]`에서 첫 번째와 마지막 요소를 교환하는 코드는?
# 32. `my_list = [1, 2, 3]`에서 두 번째 요소를 삭제하는 코드는?
# 33. `my_list = [5, 10, 15]`에서 모든 요소의 합을 구하는 코드는?
# 34. `my_list = [10, 20, 30]`의 모든 요소를 곱하는 코드는?
# 35. `x = 5`일 때, `x`를 1 증가시키는 코드는?
# 36. `x = 10`과 `y = 20`일 때, `x`와 `y`를 서로 교환하는 코드는?
# 37. `x = 5`일 때, `x`의 값을 3으로 변경하는 코드는?
# 38. 리스트 `my_list = [1, 2, 3]`의 각 요소에 2를 곱한 리스트를 만드는 코드는?
# 39. 문자열 `s = "Hello World"`에서 `H`의 위치를 찾는 코드는?
# 40. `x = 3.5`일 때, `x`를 정수로 변환하는 코드는?
# 41. `x = "100"`일 때, `x`를 정수형으로 변환한 값은?
# 42. `my_list = [10, 20, 30]`에서 두 번째 요소를 출력하는 코드는?
# 43. `for i in range(3):` 다음에 `print(i)`를 실행했을 때 출력되는 값은?
# 44. 문자열 `text = "Python"`에서 슬라이스 `text[1:4]`의 결과는?
# 45. `x = [1, 2, 3]`에서 첫 번째 요소를 `10`으로 변경하는 코드는?
# 46. `x = "apple"`에서 마지막 문자를 출력하는 코드는?
# 47. `x = 5`와 `y = 10`일 때, `x < y`의 결과는?
# 48. `x = 4`와 `y = 2`일 때, `x / y`의 결과는?
# 49. `x = "abc"`와 `y = "def"`를 합치는 코드는?
# 50. `x = 100`을 이진수로 변환하는 코드는?
# 51. `a = 3`일 때, `a + 5`의 결과는?
# 52. `b = 7`일 때, `b * 2`의 결과는?
# 53. `c = 12`일 때, `c - 4`의 결과는?
# 54. `x = 9`와 `y = 4`일 때, `x % y`의 결과는?
# 55. `x = 5`일 때, `x >= 5`의 결과는?
# 56. `x = 15`일 때, `x < 10`의 결과는?
# 57. `x = 10.0`과 `y = 3`일 때, `x // y`의 결과는?
# 58. `x = "100"`을 실수형으로 변환하는 코드는?
# 59. `my_list = [1, 2, 3, 4, 5]`에서 인덱스 1의 값을 출력하는 코드는?
# 60. `my_list = [10, 20, 30]`에서 모든 요소에 5를 더한 리스트를 만드는 코드는?
# 61. `for i in range(4):` 다음에 `print(i)`를 실행했을 때 출력되는 값은?
# 62. `my_list = [1, 2, 3]`에서 첫 번째 요소를 제거하는 코드는?
# 63. `s = "Hello"`에서 마지막 문자를 출력하는 코드는?
# 64. `x = 25`일 때, `x ** 2`의 결과는?
# 65. `my_list = [5, 10, 15]`에서 두 번째 요소를 20으로 변경하는 코드는?
# 66. `for`문을 사용하여 `my_list = [10, 20, 30]`의 각 요소를 출력하는 코드는?
# 67. `a = "abc"`와 `b = "def"`를 합치는 코드는?
# 68. `my_dict = {'name': 'Alice', 'age': 25}`에서 키 `'name'`의 값을 출력하는 코드는?
# 69. `my_dict = {'name': 'Bob'}`에 키 `'age'`와 값 `30`을 추가하는 코드는?
# 70. `x = 10`과 `y = 2`일 때, `x / y`의 결과는?
# 71. `my_list = [1, 2, 3]`에서 마지막 요소를 삭제하는 코드는?
# 72. `x = "python"`에서 대문자로 변환하는 코드는?
# 73. `my_list = [5, 10, 15]`의 모든 요소를 더하는 코드는?
# 74. `s = "Hello World"`에서 `World`를 `Python`으로 변경하는 코드는?
# 75. `x = [1, 2, 3]`에서 2번째 요소의 인덱스를 출력하는 코드는?
# 76. `x = 7`일 때, `x + 3`의 결과는?
# 77. `x = 3`일 때, `x * 5`의 결과는?
# 78. `my_list = [10, 20, 30]`의 평균을 구하는 코드는?
#
#
# 79. `my_list = [2, 4, 6]`에서 각 요소를 2배로 만드는 코드는?
# 80. `x = "123"`을 정수형으로 변환하는 코드는?
# 81. `for`문을 사용하여 리스트 `my_list = [1, 2, 3, 4]`의 요소를 출력하는 코드는?
# 82. `my_list = ['a', 'b', 'c']`에서 두 번째 요소를 출력하는 코드는?
# 83. `x = 3.14`일 때, `x`를 정수로 변환하는 코드는?
# 84. `my_list = [5, 10, 15]`에서 첫 번째 요소를 100으로 변경하는 코드는?
# 85. `x = "apple"`에서 길이를 구하는 코드는?
# 86. `my_list = [1, 2, 3]`에서 모든 요소의 제곱을 구하는 코드는?
# 87. `x = 8`일 때, `x % 2`의 결과는?
# 88. `s = "    Hello    "`에서 공백을 제거하는 코드는?
# 89. `my_list = [1, 3, 5]`에서 첫 번째와 세 번째 요소를 더하는 코드는?
# 90. `my_list = [1, 2, 3]`의 길이를 구하는 코드는?
# 91. `x = 12`일 때, `x // 5`의 결과는?
# 92. `my_dict = {'a': 1}`에 키 `'b'`와 값 `2`를 추가하는 코드는?
# 93. `my_list = [1, 2, 3]`의 첫 번째 요소를 출력하는 코드는?
# 94. `x = "Hello"`의 대문자를 출력하는 코드는?
# 95. `my_list = [1, 2, 3]`에서 두 번째 요소를 삭제하는 코드는?
# 96. `my_list = [1, 2, 3]`의 마지막 요소를 출력하는 코드는?
# 97. `x = 5`일 때, `x == 5`의 결과는?
# 98. `my_list = [2, 4, 6]`에서 각 요소를 3배로 만드는 코드는?
# 99. `my_list = [1, 2, 3]`의 평균을 구하는 코드는?
# 100. `x = "100"`을 실수형으로 변환하는 코드는?

# %% [markdown]
# ### 답
#
# 1. `15`
# 2. `True`
# 3. `str(x)`
# 4. `6`
# 5. `30`
# 6. `3`
# 7. `True`
# 8. `float(x)`
# 9. `int(x)`
# 10. `15`
# 11. `3`
# 12. `'banana'`
# 13. `fruits.append('orange')`
# 14. `my_list[-1]`
# 15. `'H'`
# 16. `33`
# 17. `49`
# 18. `len(numbers)`
# 19. `values[1] = 20`
# 20. `x.index("P")`
# 21. `s.strip()`
# 22. `[i + 2 for i in my_list]`
# 23. `my_dict['b']`
# 24. `my_dict['c'] = 3`
# 25. `x.upper()`
# 26. `int(x)`
# 27. `[i ** 2 for i in x]`
# 28. `for i in my_list: print(i)`
# 29. `for i in range(5): print(i)`
# 30. `print("x is greater than 5")`
# 31. `my_list[0], my_list[-1] = my_list[-1], my_list[0]`
# 32. `my_list.pop(1)`
# 33. `sum(my_list)`
# 34. `import functools; functools.reduce(lambda a, b: a * b, my_list)`
# 35. `x += 1`
# 36. `x, y = y, x`
# 37. `x = 3`
# 38. `[i * 2 for i in my_list]`
# 39. `s.find("H")`
# 40. `int(x)`
# 41. `100`
# 42. `my_list[1]`
# 43. `0`, `1`, `2`
# 44. `'yth'`
# 45. `x[0] = 10`
# 46. `x[-1]`
# 47. `True`
# 48. `2.0`
# 49. `x + y`
# 50. `bin(x)[2:]`
# 51. `8`
# 52. `14`
# 53. `8`
# 54. `1`
# 55. `True`
# 56. `False`
# 57. `5.0`
# 58. `float(x)`
# 59. `my_list[1]`
# 60. `[i + 5 for i in my_list]`
# 61. `0`, `1`, `2`, `3`
# 62. `my_list.pop(0)`
# 63. `s[-1]`
# 64. `625`
# 65. `values[1] = 20`
# 66. `for i in my_list: print(i)`
# 67. `a + b`
# 68. `my_dict['name']`
# 69. `my_dict['age'] = 30`
# 70. `5.0`
# 71. `my_list.pop()`
# 72. `x.upper()`
# 73. `sum(my_list)`
# 74. `s.replace("World", "Python")`
# 75. `1`
# 76. `10`
# 77. `15`
# 78. `sum(my_list) / len(my_list)`
# 79. `[i * 2 for i in my_list]`
# 80. `int(x)`
# 81. `for i in my_list: print(i)`
# 82. `my_list[1]`
# 83. `int(x)`
# 84. `my_list[0] = 100`
# 85. `len(x)`
# 86. `[i ** 2 for i in my_list]`
# 87. `0`
# 88. `s.strip()`
# 89. `my_list[0] + my_list[2]`
# 90. `len(my_list)`
# 91. `2`
# 92. `my_dict['b'] = 2`
# 93. `my_list[0]`
# 94. `x.upper()`
# 95. `my_list.pop(1)`
# 96. `my_list[-1]`
# 97. `True`
# 98. `[i * 3 for i in my_list]`
# 99. `sum(my_list) / len(my_list)`
# 100. `float(x)`
